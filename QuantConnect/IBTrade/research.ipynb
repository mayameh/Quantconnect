# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
# QuantBook Analysis Tool
# For more information see [https://www.quantconnect.com/docs/v2/our-platform/research/getting-started]
qb = QuantBook()

AAPL_equity_obj = qb.AddEquity("AAPL", Resolution.DAILY)

AAPL_equity_symb = AAPL_equity_obj.symbol

AAPL_history = qb.history(qb.securities.keys(), 360, Resolution.DAILY)
pd.set_option('display.width',1000)
print(AAPL_history)
# Indicator Analysis
# bbdf = qb.indicator(BollingerBands(30, 2), AAPL_equity_symb, 360, Resolution.DAILY)
# bbdf.drop('standarddeviation', axis=1).plot()
